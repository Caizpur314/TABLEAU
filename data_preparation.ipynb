# %%
import pandas as pd

# %%
jan_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201801-citibike-tripdata.csv")
jan_2018.head()
# Out:
#      DATE  tripduration starttime stoptime  start station id  \
# 0  Jan-18           932   06:17.5  21:50.0              3183
# 1  Jan-18           550   06:18.0  15:28.4              3183
# 2  Jan-18           510   06:57.0  15:27.8              3183
# 3  Jan-18           354   53:10.2  59:05.1              3183
# 4  Jan-18           250   34:30.2  38:41.0              3183
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3     Exchange Place               40.716247               -74.033459
# 4     Exchange Place               40.716247               -74.033459
#
#    end station id end station name  end station latitude  \
# 0            3199     Newport Pkwy             40.728745
# 1            3199     Newport Pkwy             40.728745
# ...

# %%
feb_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201802-citibike-tripdata.csv")

# %%
mar_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201803-citibike-tripdata.csv")

# %%
apr_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201804-citibike-tripdata.csv")

# %%
may_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201805-citibike-tripdata.csv")

# %%
jun_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201806-citibike-tripdata.csv")

# %%
jul_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201807-citibike-tripdata.csv")

# %%
aug_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201808-citibike-tripdata.csv")

# %%
sep_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201809-citibike-tripdata.csv")

# %%
oct_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201810-citibike-tripdata.csv")

# %%
nov_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201811-citibike-tripdata.csv")

# %%
dec_2018 = pd.read_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/JC-201812-citibike-tripdata.csv")

# %%
#let's concatenate the data
bike_data_2018 = pd.concat([jan_2018, feb_2018, mar_2018, apr_2018, may_2018, jun_2018, jul_2018, aug_2018, sep_2018, oct_2018, nov_2018, dec_2018])
bike_data_2018
# Out:
#          DATE  tripduration starttime stoptime  start station id  \
# 0      Jan-18           932   06:17.5  21:50.0              3183
# 1      Jan-18           550   06:18.0  15:28.4              3183
# 2      Jan-18           510   06:57.0  15:27.8              3183
# 3      Jan-18           354   53:10.2  59:05.1              3183
# 4      Jan-18           250   34:30.2  38:41.0              3183
# 5      Jan-18           613   05:05.9  15:19.4              3183
# 6      Jan-18           290   13:51.8  18:42.1              3183
# 7      Jan-18           381   50:03.3  56:24.6              3183
# 8      Jan-18           318   55:58.2  01:16.9              3183
# 9      Jan-18          1852   55:29.6  26:22.3              3183
# 10     Jan-18           460   01:50.6  09:31.4              3183
# 11     Jan-18           403   05:12.2  11:55.3              3183
# 12     Jan-18           264   05:12.7  09:37.4              3183
# ...

# %%
# Remove the rows with missing data
bike_data_2018 = bike_data_2018.dropna(how="any")
bike_data_2018.count()
# Out:
# DATE                       353892
# tripduration               353892
# starttime                  353892
# stoptime                   353892
# start station id           353892
# start station name         353892
# start station latitude     353892
# start station longitude    353892
# end station id             353892
# end station name           353892
# end station latitude       353892
# end station longitude      353892
# bikeid                     353892
# usertype                   353892
# birth year                 353892
# gender                     353892
# dtype: int64

# %%
bike_data_2018.to_csv("C:/Users/CAEAIZPU/OneDrive - kochind.com/Desktop/Tableau/bike_data_2018.csv")
